# %%
from stocksymbol import StockSymbol

# %%
api_key = '42894040-5378-4a5a-bfc3-2948740bdb2a'
ss = StockSymbol(api_key)

# get symbol list based on market
symbol_list_us = ss.get_symbol_list(market="US") # "us" or "america" will also work

# get symbol list based on index
symbol_list_spx = ss.get_symbol_list(index="SPX")

# show a list of available market
market_list = ss.market_list

# show a list of available index
index_list = ss.index_list

# %%
index_list
# Out:
# [{'market': 'singapore',
#   'abbreviation': 'sg',
#   'indexId': 'STI',
#   'indexName': 'STRAITS TIMES INDEX'},
#  {'market': 'thailand',
#   'abbreviation': 'th',
#   'indexId': 'SET100',
#   'indexName': 'SET100 INDEX'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XUTEK',
#   'indexName': 'BIST TEKNOLOJI'},
#  {'market': 'thailand',
#   'abbreviation': 'th',
#   'indexId': 'SET50',
#   'indexName': 'SET50 INDEX'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XUTUM',
#   'indexName': 'BIST TUM'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XGIDA',
#   'indexName': 'BIST GIDA ICECEK'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XSPOR',
#   'indexName': 'BIST SPOR'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XU050',
#   'indexName': 'BIST 50'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XU100',
#   'indexName': 'BIST 100'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXEU',
#   'indexName': 'MOEX ELECTRIC UTILITIES INDEX'},
#  {'market': 'portugal',
#   'abbreviation': 'pt',
#   'indexId': 'PSI20',
#   'indexName': 'PSI 20'},
#  {'market': 'portugal',
#   'abbreviation': 'pt',
#   'indexId': 'SXXP_PT',
#   'indexName': 'STOXX 600'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XU030',
#   'indexName': 'BIST 30'},
#  {'market': 'turkey',
#   'abbreviation': 'tr',
#   'indexId': 'XBANK',
#   'indexName': 'BIST BANKA'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXCN',
#   'indexName': 'MOEX CONSUMER INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXCH',
#   'indexName': 'MOEX CHEMICALS INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXMM',
#   'indexName': 'MOEX METALS AND MINING INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'RTSCH',
#   'indexName': 'RTS CHEMICALS INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'RTSI',
#   'indexName': 'RTS INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'RUBMI',
#   'indexName': 'RTS BROAD MARKET INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXTL',
#   'indexName': 'MOEX TELECOMMUNICATION INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXINN',
#   'indexName': 'MOEX INNOVATION INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXFN',
#   'indexName': 'MOEX FINANCIALS INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXBMI',
#   'indexName': 'MOEX BROAD MARKET INDEX (RUB)'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MCXSM',
#   'indexName': 'MOEX SMID INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEXTN',
#   'indexName': 'MOEX TRANSPORT INDEX'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'MOEX10',
#   'indexName': 'MOEX 10 INDEX'},
#  {'market': 'sweden',
#   'abbreviation': 'se',
#   'indexId': 'OMXS30',
#   'indexName': 'OMX STOCKHOLM 30 INDEX'},
#  {'market': 'sweden',
#   'abbreviation': 'se',
#   'indexId': 'SXXP_SE',
#   'indexName': 'STOXX 600'},
#  {'market': 'netherlands',
#   'abbreviation': 'nl',
#   'indexId': 'SXXP_NL',
#   'indexName': 'STOXX 600'},
#  {'market': 'netherlands',
#   'abbreviation': 'nl',
#   'indexId': 'AEX',
#   'indexName': 'AEX-INDEX'},
#  {'market': 'latvia',
#   'abbreviation': 'lv',
#   'indexId': 'OMXRGI',
#   'indexName': 'OMX RIGA GI'},
#  {'market': 'newzealand',
#   'abbreviation': 'nz',
#   'indexId': 'NZ50G',
#   'indexName': 'S&P/NZX 50 INDEX GROSS ( GROSS INDEX )'},
#  {'market': 'poland',
#   'abbreviation': 'pl',
#   'indexId': 'SXXP_PL',
#   'indexName': 'STOXX 600'},
#  {'market': 'russia',
#   'abbreviation': 'ru',
#   'indexId': 'IMOEX',
#   'indexName': 'MOEX RUSSIA INDEX'},
#  {'market': 'lithuania',
#   'abbreviation': 'lt',
#   'indexId': 'OMXVGI',
#   'indexName': 'OMX VILNIUS GI'},
#  {'market': 'israel',
#   'abbreviation': 'il',
#   'indexId': 'TA35',
#   'indexName': 'TA-35'},
#  {'market': 'israel',
#   'abbreviation': 'il',
#   'indexId': 'TA125',
#   'indexName': 'TA-125'},
#  {'market': 'iceland',
#   'abbreviation': 'is',
#   'indexId': 'OMXI10',
#   'indexName': 'OMX ICELAND 10'},
#  {'market': 'india',
#   'abbreviation': 'in',
#   'indexId': 'SENSEX',
#   'indexName': 'S&P BSE SENSEX'},
#  {'market': 'norway',
#   'abbreviation': 'no',
#   'indexId': 'SXXP_NO',
#   'indexName': 'STOXX 600'},
#  {'market': 'india',
#   'abbreviation': 'in',
#   'indexId': 'NIFTY',
#   'indexName': 'NIFTY 50'},
#  {'market': 'india',
#   'abbreviation': 'in',
#   'indexId': 'BANKNIFTY',
#   'indexName': 'NIFTY BANK'},
#  {'market': 'netherlands',
#   'abbreviation': 'nl',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'spain',
#   'abbreviation': 'es',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'italy',
#   'abbreviation': 'it',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'italy',
#   'abbreviation': 'it',
#   'indexId': 'SXXP_IT',
#   'indexName': 'STOXX 600'},
#  {'market': 'china',
#   'abbreviation': 'cn',
#   'indexId': 'HSI',
#   'indexName': 'HANG SENG INDEX'},
#  {'market': 'finland',
#   'abbreviation': 'fi',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'switzerland',
#   'abbreviation': 'ch',
#   'indexId': 'SXXP_CH',
#   'indexName': 'STOXX 600'},
#  {'market': 'spain',
#   'abbreviation': 'es',
#   'indexId': 'SXXP_ES',
#   'indexName': 'STOXX 600'},
#  {'market': 'finland',
#   'abbreviation': 'fi',
#   'indexId': 'SXXP_FI',
#   'indexName': 'STOXX 600'},
#  {'market': 'finland',
#   'abbreviation': 'fi',
#   'indexId': 'OMXH25',
#   'indexName': 'OMX HELSINKI 25'},
#  {'market': 'italy',
#   'abbreviation': 'it',
#   'indexId': 'FTSEMIB',
#   'indexName': 'FTSE MIB INDEX'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'SXXP_DE',
#   'indexName': 'STOXX 600'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'SDXP',
#   'indexName': 'SDAX PERFORMANCEINDEX'},
#  {'market': 'denmark',
#   'abbreviation': 'dk',
#   'indexId': 'OMXC25',
#   'indexName': 'OMX COPENHAGEN 25 INDEX'},
#  {'market': 'denmark',
#   'abbreviation': 'dk',
#   'indexId': 'SXXP_DK',
#   'indexName': 'STOXX 600'},
#  {'market': 'belgium',
#   'abbreviation': 'be',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'TDXP',
#   'indexName': 'TECDAX TR'},
#  {'market': 'belgium',
#   'abbreviation': 'be',
#   'indexId': 'BEL20',
#   'indexName': 'BEL 20'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'MDAX',
#   'indexName': 'MDAX PERFORMANCE-INDEX'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'germany',
#   'abbreviation': 'de',
#   'indexId': 'DAX',
#   'indexName': 'DAX INDEX'},
#  {'market': 'china',
#   'abbreviation': 'cn',
#   'indexId': '399001',
#   'indexName': 'SHENZHEN COMPONENT INDEX'},
#  {'market': 'brazil',
#   'abbreviation': 'br',
#   'indexId': 'IFIX',
#   'indexName': 'IND FDO IMOB'},
#  {'market': 'brazil',
#   'abbreviation': 'br',
#   'indexId': 'IBXL',
#   'indexName': 'IBRX 50'},
#  {'market': 'brazil',
#   'abbreviation': 'br',
#   'indexId': 'IBOV',
#   'indexName': 'BOVESPA INDEX'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'SPF',
#   'indexName': 'S&P 500 Financials'},
#  {'market': 'argentina',
#   'abbreviation': 'ar',
#   'indexId': 'IMV',
#   'indexName': 'S&P/BYMA ARGENTINA GENERAL PANEL MERVAL EQUITIES'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'INSR',
#   'indexName': 'NASDAQ INSURANCE'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'SPN',
#   'indexName': 'S&P 500 Energy'},
#  {'market': 'australia',
#   'abbreviation': 'au',
#   'indexId': 'XJO',
#   'indexName': 'S&P/ASX 200'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'UTY',
#   'indexName': 'PHLX UTILITY SECTOR'},
#  {'market': 'canada',
#   'abbreviation': 'ca',
#   'indexId': 'TSX',
#   'indexName': 'S&P/TSX COMPOSITE INDEX'},
#  {'market': 'belgium',
#   'abbreviation': 'be',
#   'indexId': 'SXXP_BE',
#   'indexName': 'STOXX 600'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5CONS',
#   'indexName': 'S&P 500 Consumer Staples'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5COND',
#   'indexName': 'S&P 500 Consumer Discretionary'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'SOX',
#   'indexName': 'PHLX SEMICONDUCTOR'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'DJUSCL',
#   'indexName': 'Dow Jones U.S. Coal'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'DJI',
#   'indexName': 'Dow Jones Industrial Average'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5UTIL',
#   'indexName': 'S&P 500 Utilities'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'XMI',
#   'indexName': 'NYSE ARCA MAJOR MARKET'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5HLTH',
#   'indexName': 'S&P 500 Health Care'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5INFT',
#   'indexName': 'S&P 500 Information Technology'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5REAS',
#   'indexName': 'S&P 500 Real Estate'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5INDU',
#   'indexName': 'S&P 500 Industrials'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'MID',
#   'indexName': 'S&P 400'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'INDS',
#   'indexName': 'NASDAQ INDUSTRIAL'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'OEX',
#   'indexName': 'S&P 100'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'DJU',
#   'indexName': 'Dow Jones Utility Average'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5TELS',
#   'indexName': 'S&P 500 Communication Services'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'NDX',
#   'indexName': 'NASDAQ 100'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'TRAN',
#   'indexName': 'NASDAQ TRANSPORTATION'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'IXCO',
#   'indexName': 'NASDAQ COMPUTER'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'DJT',
#   'indexName': 'Dow Jones Transportation Average'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'IXTC',
#   'indexName': 'NASDAQ TELECOMMUNICATIONS'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'OSX',
#   'indexName': 'PHLX OIL SERVICE SECTOR'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'S5MATR',
#   'indexName': 'S&P 500 Materials'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'HGX',
#   'indexName': 'PHLX HOUSING SECTOR'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'SPX',
#   'indexName': 'S&P 500'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'OFIN',
#   'indexName': 'NASDAQ OTHER FINANCE'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'IXIC',
#   'indexName': 'NASDAQ COMPOSITE'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'DJA',
#   'indexName': 'Dow Jones Composite Average'},
#  {'market': 'france',
#   'abbreviation': 'fr',
#   'indexId': 'SXXP_FR',
#   'indexName': 'STOXX 600'},
#  {'market': 'france',
#   'abbreviation': 'fr',
#   'indexId': 'PX1',
#   'indexName': 'CAC 40'},
#  {'market': 'france',
#   'abbreviation': 'fr',
#   'indexId': 'SX5E',
#   'indexName': 'STOXX 50'},
#  {'market': 'america',
#   'abbreviation': 'us',
#   'indexId': 'XAU',
#   'indexName': 'PHLX GOLD AND SILVER SECTOR INDEX'},
#  {'market': 'unitedkingdom',
#   'abbreviation': 'gb',
#   'indexId': 'UKX',
#   'indexName': 'UK 100 INDEX'},
#  {'market': 'unitedkingdom',
#   'abbreviation': 'gb',
#   'indexId': 'SXXP_GB',
#   'indexName': 'STOXX 600'},
#  {'market': 'Europe',
#   'abbreviation': 'eu',
#   'indexId': 'SXXP',
#   'indexName': 'SXXPQuotes'},
#  {'market': 'japan',
#   'abbreviation': 'jp',
#   'indexId': 'NI225',
#   'indexName': 'NIKKEI 225'}]

# %%
import pandas as pd
df = pd.DataFrame(symbol_list_us)
df[df.longName.str.contains("Sculptor")]
# Out:
#       symbol shortName                           longName exchange     market  \
# 2846     SCU            Sculptor Capital Management, Inc.     NYSE  us_market
# 5407  SCUA.U                  Sculptor Acquisition Corp I     NYSE  us_market
#
#      quoteType
# 2846    EQUITY
# 5407    EQUITY

# %%
df[df.longName.str.contains("Aetna")]
# Out:
# Empty DataFrame
# Columns: [symbol, shortName, longName, exchange, market, quoteType]
# Index: []

# %%
df[df.symbol.str.contains("AET")]
# Out:
# Empty DataFrame
# Columns: [symbol, shortName, longName, exchange, market, quoteType]
# Index: []
