# %% [markdown]
# # **How to train your <del>dragon</del> custom word embeddings**
#
# In the [baseline-keras-lstm-is-all-you-need](https://www.kaggle.com/huikang/baseline-keras-lstm-is-all-you-need) notebook shared by Hui Kang (thanks again!), it was demonstrated that a LSTM model using generic global vector (GLOVE) achieved a pretty solid benchmark results.
#
# After playing around with GLOVE, you will quickly find that certain words in your training data are not present in its vocab. These are typically replaced with same-shape zero vector, which essentially means you are 'sacrificing' the word as your input feature, which can potentially be important for correct prediction. Another way to deal with this is to train your own word embeddings, using your training data, so that the semantic relationship of your own training corpus can be better represented.
#
# In this notebook, I will demonstrate how to train your custom word2vec using Gensim.
#
# For those who are new to word embeddings and would like to find out more, you can check out the following articles:
# 1. [Introduction to Word Embedding and Word2Vec](https://towardsdatascience.com/introduction-to-word-embedding-and-word2vec-652d0c2060fa)
# 2. [A Beginner's Guide to Word2Vec and Neural Word Embeddings](https://skymind.ai/wiki/word2vec)

# %%
import numpy as np
import pandas as pd
import os
import re
import time

from gensim.models import Word2Vec
from tqdm import tqdm

tqdm.pandas()

# %%
def preprocessing(titles_array):
    
    """
    Take in an array of titles, and return the processed titles.
    
    (e.g. input: 'i am a boy', output - 'am boy')  -> since I remove those words with length 1
    
    Feel free to change the preprocessing steps and see how it affects the modelling results!
    """
    
    processed_array = []
    
    for title in tqdm(titles_array):
        
        # remove other non-alphabets symbols with space (i.e. keep only alphabets and whitespaces).
        processed = re.sub('[^a-zA-Z ]', '', title)
        
        words = processed.split()
        
        # keep words that have length of more than 1 (e.g. gb, bb), remove those with length 1.
        processed_array.append(' '.join([word for word in words if len(word) > 1]))
    
    return processed_array

# %% [markdown]
# ## **Something to take note**
# Word2vec is a **self-supervised** method (well, sort of unsupervised but not unsupervised, since it provides its own labels. check out this [Quora](https://www.quora.com/Is-Word2vec-a-supervised-unsupervised-learning-algorithm) thread for a more detailed explanation), so we can make full use of the entire dataset (including test data) to obtain a more wholesome word embedding representation.

# %%
df_train = pd.read_csv('SEC-CompanyTicker.csv')
df_test = pd.read_csv('SEC-CompanyTicker.csv')

# %%
df_train = df_train.rename(columns={"companyName":"title"}).head(100)
df_test = df_test.rename(columns={"companyName":"title"})
df_train
# Out:
#     Unnamed: 0  cik_str ticker                       title
# 0            0   320193   AAPL                  Apple Inc.
# 1            1   789019   MSFT              Microsoft Corp
# 2            2  1652044  GOOGL               Alphabet Inc.
# 3            3  1018724   AMZN              Amazon Com Inc
# 4            4  1045810   NVDA                 Nvidia Corp
# ..         ...      ...    ...                         ...
# 95          95  1075531   BKNG       Booking Holdings Inc.
# 96          96   829224   SBUX              Starbucks Corp
# 97          97  1668717    BUD  Anheuser-Busch Inbev Sa/Nv
# 98          98   947263     TD       Toronto Dominion Bank
# 99          99   101829    RTX                    Rtx Corp
#
# [100 rows x 4 columns]

# %%
df_train['processed'] = preprocessing(df_train['title'])
df_test['processed'] = preprocessing(df_test['title'])

sentences = pd.concat([df_train['processed'], df_test['processed']],axis=0)
train_sentences = list(sentences.progress_apply(str.split).values)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 78120.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 10898/10898 [00:00<00:00, 541864.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 10998/10998 [00:00<00:00, 1208038.64it/s]

# %%
train_sentences
# Out:
# [['Apple', 'Inc'],
#  ['Microsoft', 'Corp'],
#  ['Alphabet', 'Inc'],
#  ['Amazon', 'Com', 'Inc'],
#  ['Nvidia', 'Corp'],
#  ['Tesla', 'Inc'],
#  ['Berkshire', 'Hathaway', 'Inc'],
#  ['Meta', 'Platforms', 'Inc'],
#  ['Eli', 'Lilly', 'Co'],
#  ['Visa', 'Inc'],
#  ['Taiwan', 'Semiconductor', 'Manufacturing', 'Co', 'Ltd'],
#  ['Exxon', 'Mobil', 'Corp'],
#  ['Unitedhealth', 'Group', 'Inc'],
#  ['Walmart', 'Inc'],
#  ['Novo', 'Nordisk'],
#  ['Jpmorgan', 'Chase', 'Co'],
#  ['Spdr', 'SP', 'Etf', 'Trust'],
#  ['Johnson', 'Johnson'],
#  ['Mastercard', 'Inc'],
#  ['Lvmh', 'Moet', 'Hennessy', 'Louis', 'Vuitton'],
#  ['Procter', 'Gamble', 'Co'],
#  ['Broadcom', 'Inc'],
#  ['Latam', 'Airlines', 'Group', 'SA'],
#  ['Home', 'Depot', 'Inc'],
#  ['Chevron', 'Corp'],
#  ['Oracle', 'Corp'],
#  ['Merck', 'Co', 'Inc'],
#  ['Abbvie', 'Inc'],
#  ['Coca', 'Cola', 'Co'],
#  ['Adobe', 'Inc'],
#  ['Toyota', 'Motor', 'Corp'],
#  ['Pepsico', 'Inc'],
#  ['Costco', 'Wholesale', 'Corp', 'New'],
#  ['Asml', 'Holding', 'Nv'],
#  ['Bank', 'Of', 'America', 'Corp', 'De'],
#  ['Cisco', 'Systems', 'Inc'],
#  ['Alibaba', 'Group', 'Holding', 'Ltd'],
#  ['Salesforce', 'Inc'],
#  ['Shell', 'Plc'],
#  ['Astrazeneca', 'Plc'],
#  ['Novartis', 'Ag'],
#  ['Mcdonalds', 'Corp'],
#  ['Accenture', 'Plc'],
#  ['Thermo', 'Fisher', 'Scientific', 'Inc'],
#  ['Mexican', 'Economic', 'Development', 'Inc'],
#  ['Pfizer', 'Inc'],
#  ['Linde', 'Plc'],
#  ['Danaher', 'Corp', 'De'],
#  ['Comcast', 'Corp'],
#  ['Netflix', 'Inc'],
#  ['Abbott', 'Laboratories'],
#  ['Advanced', 'Micro', 'Devices', 'Inc'],
#  ['TMobile', 'Us', 'Inc'],
#  ['Hdfc', 'Bank', 'Ltd'],
#  ['Intel', 'Corp'],
#  ['Sap', 'Se'],
#  ['Totalenergies', 'Se'],
#  ['Wells', 'Fargo', 'CompanyMn'],
#  ['Walt', 'Disney', 'Co'],
#  ['Intuit', 'Inc'],
#  ['Hsbc', 'Holdings', 'Plc'],
#  ['Texas', 'Instruments', 'Inc'],
#  ['Philip', 'Morris', 'International', 'Inc'],
#  ['Nike', 'Inc'],
#  ['Invesco', 'Qqq', 'Trust', 'Series'],
#  ['Conocophillips'],
#  ['Morgan', 'Stanley'],
#  ['Bhp', 'Group', 'Ltd'],
#  ['Verizon', 'Communications', 'Inc'],
#  ['Caterpillar', 'Inc'],
#  ['Nextera', 'Energy', 'Inc'],
#  ['Amgen', 'Inc'],
#  ['Blackstone', 'Inc'],
#  ['Sanofi'],
#  ['United', 'Parcel', 'Service', 'Inc'],
#  ['International', 'Business', 'Machines', 'Corp'],
#  ['Lowes', 'Companies', 'Inc'],
#  ['Pdd', 'Holdings', 'Inc'],
#  ['Union', 'Pacific', 'Corp'],
#  ['Honeywell', 'International', 'Inc'],
#  ['Unilever', 'Plc'],
#  ['Qualcomm', 'IncDe'],
#  ['Boeing', 'Co'],
#  ['Royal', 'Bank', 'Of', 'Canada'],
#  ['Bristol', 'Myers', 'Squibb', 'Co'],
#  ['SP', 'Global', 'Inc'],
#  ['General', 'Electric', 'Co'],
#  ['Applied', 'Materials', 'Inc', 'De'],
#  ['Rio', 'Tinto', 'Ltd'],
#  ['Servicenow', 'Inc'],
#  ['American', 'Express', 'Co'],
#  ['Deere', 'Co'],
#  ['Airbus', 'SeAdr'],
#  ['Stryker', 'Corp'],
#  ['Prologis', 'Inc'],
#  ['Booking', 'Holdings', 'Inc'],
#  ['Starbucks', 'Corp'],
#  ['AnheuserBusch', 'Inbev', 'SaNv'],
#  ['Toronto', 'Dominion', 'Bank'],
#  ['Rtx', 'Corp'],
#  ['Apple', 'Inc'],
#  ['Microsoft', 'Corp'],
#  ['Alphabet', 'Inc'],
#  ['Amazon', 'Com', 'Inc'],
#  ['Nvidia', 'Corp'],
#  ['Tesla', 'Inc'],
#  ['Berkshire', 'Hathaway', 'Inc'],
#  ['Meta', 'Platforms', 'Inc'],
#  ['Eli', 'Lilly', 'Co'],
#  ['Visa', 'Inc'],
#  ['Taiwan', 'Semiconductor', 'Manufacturing', 'Co', 'Ltd'],
#  ['Exxon', 'Mobil', 'Corp'],
#  ['Unitedhealth', 'Group', 'Inc'],
#  ['Walmart', 'Inc'],
#  ['Novo', 'Nordisk'],
#  ['Jpmorgan', 'Chase', 'Co'],
#  ['Spdr', 'SP', 'Etf', 'Trust'],
#  ['Johnson', 'Johnson'],
#  ['Mastercard', 'Inc'],
#  ['Lvmh', 'Moet', 'Hennessy', 'Louis', 'Vuitton'],
#  ['Procter', 'Gamble', 'Co'],
#  ['Broadcom', 'Inc'],
#  ['Latam', 'Airlines', 'Group', 'SA'],
#  ['Home', 'Depot', 'Inc'],
#  ['Chevron', 'Corp'],
#  ['Oracle', 'Corp'],
#  ['Merck', 'Co', 'Inc'],
#  ['Abbvie', 'Inc'],
#  ['Coca', 'Cola', 'Co'],
#  ['Adobe', 'Inc'],
#  ['Toyota', 'Motor', 'Corp'],
#  ['Pepsico', 'Inc'],
#  ['Costco', 'Wholesale', 'Corp', 'New'],
#  ['Asml', 'Holding', 'Nv'],
#  ['Bank', 'Of', 'America', 'Corp', 'De'],
#  ['Cisco', 'Systems', 'Inc'],
#  ['Alibaba', 'Group', 'Holding', 'Ltd'],
#  ['Salesforce', 'Inc'],
#  ['Shell', 'Plc'],
#  ['Astrazeneca', 'Plc'],
#  ['Novartis', 'Ag'],
#  ['Mcdonalds', 'Corp'],
#  ['Accenture', 'Plc'],
#  ['Thermo', 'Fisher', 'Scientific', 'Inc'],
#  ['Mexican', 'Economic', 'Development', 'Inc'],
#  ['Pfizer', 'Inc'],
#  ['Linde', 'Plc'],
#  ['Danaher', 'Corp', 'De'],
#  ['Comcast', 'Corp'],
#  ['Netflix', 'Inc'],
#  ['Abbott', 'Laboratories'],
#  ['Advanced', 'Micro', 'Devices', 'Inc'],
#  ['TMobile', 'Us', 'Inc'],
#  ['Hdfc', 'Bank', 'Ltd'],
#  ['Intel', 'Corp'],
#  ['Sap', 'Se'],
#  ['Totalenergies', 'Se'],
#  ['Wells', 'Fargo', 'CompanyMn'],
#  ['Walt', 'Disney', 'Co'],
#  ['Intuit', 'Inc'],
#  ['Hsbc', 'Holdings', 'Plc'],
#  ['Texas', 'Instruments', 'Inc'],
#  ['Philip', 'Morris', 'International', 'Inc'],
#  ['Nike', 'Inc'],
#  ['Invesco', 'Qqq', 'Trust', 'Series'],
#  ['Conocophillips'],
#  ['Morgan', 'Stanley'],
#  ['Bhp', 'Group', 'Ltd'],
#  ['Verizon', 'Communications', 'Inc'],
#  ['Caterpillar', 'Inc'],
#  ['Nextera', 'Energy', 'Inc'],
#  ['Amgen', 'Inc'],
#  ['Blackstone', 'Inc'],
#  ['Sanofi'],
#  ['United', 'Parcel', 'Service', 'Inc'],
#  ['International', 'Business', 'Machines', 'Corp'],
#  ['Lowes', 'Companies', 'Inc'],
#  ['Pdd', 'Holdings', 'Inc'],
#  ['Union', 'Pacific', 'Corp'],
#  ['Honeywell', 'International', 'Inc'],
#  ['Unilever', 'Plc'],
#  ['Qualcomm', 'IncDe'],
#  ['Boeing', 'Co'],
#  ['Royal', 'Bank', 'Of', 'Canada'],
#  ['Bristol', 'Myers', 'Squibb', 'Co'],
#  ['SP', 'Global', 'Inc'],
#  ['General', 'Electric', 'Co'],
#  ['Applied', 'Materials', 'Inc', 'De'],
#  ['Rio', 'Tinto', 'Ltd'],
#  ['Servicenow', 'Inc'],
#  ['American', 'Express', 'Co'],
#  ['Deere', 'Co'],
#  ['Airbus', 'SeAdr'],
#  ['Stryker', 'Corp'],
#  ['Prologis', 'Inc'],
#  ['Booking', 'Holdings', 'Inc'],
#  ['Starbucks', 'Corp'],
#  ['AnheuserBusch', 'Inbev', 'SaNv'],
#  ['Toronto', 'Dominion', 'Bank'],
#  ['Rtx', 'Corp'],
#  ['Goldman', 'Sachs', 'Group', 'Inc'],
#  ['Bp', 'Plc'],
#  ['Mitsubishi', 'Ufj', 'Financial', 'Group', 'Inc'],
#  ['Medtronic', 'Plc'],
#  ['Schwab', 'Charles', 'Corp'],
#  ['Intuitive', 'Surgical', 'Inc'],
#  ['Tjx', 'Companies', 'Inc', 'De'],
#  ['Lockheed', 'Martin', 'Corp'],
#  ['Sony', 'Group', 'Corp'],
#  ['Elevance', 'Health', 'Inc'],
#  ['AtT', 'Inc'],
#  ['Blackrock', 'Inc'],
#  ['Rio', 'Tinto', 'Plc'],
#  ['Automatic', 'Data', 'Processing', 'Inc'],
#  ['Uber', 'Technologies', 'Inc'],
#  ['Marsh', 'Mclennan', 'Companies', 'Inc'],
#  ['Petrobras', 'Petroleo', 'Brasileiro', 'Sa'],
#  ['Mondelez', 'International', 'Inc'],
#  ['Gilead', 'Sciences', 'Inc'],
#  ['Equinor', 'Asa'],
#  ['Airbnb', 'Inc'],
#  ['Eaton', 'Corp', 'Plc'],
#  ['Cvs', 'Health', 'Corp'],
#  ['Regeneron', 'Pharmaceuticals', 'Inc'],
#  ['Vertex', 'Pharmaceuticals', 'Inc', 'Ma'],
#  ['Diageo', 'Plc'],
#  ['Analog', 'Devices', 'Inc'],
#  ['Lam', 'Research', 'Corp'],
#  ['Schlumberger', 'LimitedNv'],
#  ['Chubb', 'Ltd'],
#  ['Cigna', 'Group'],
#  ['Ubs', 'Group', 'Ag'],
#  ['Icici', 'Bank', 'Ltd'],
#  ['Zoetis', 'Inc'],
#  ['Csl', 'Ltd'],
#  ['Shopify', 'Inc'],
#  ['American', 'Tower', 'Corp', 'Ma'],
#  ['Citigroup', 'Inc'],
#  ['Progressive', 'CorpOh'],
#  ['Altria', 'Group', 'Inc'],
#  ['Boston', 'Scientific', 'Corp'],
#  ['Micron', 'Technology', 'Inc'],
#  ['Eog', 'Resources', 'Inc'],
#  ['Becton', 'Dickinson', 'Co'],
#  ['Daimler', 'Ag'],
#  ['Southern', 'Co'],
#  ['Palo', 'Alto', 'Networks', 'Inc'],
#  ['Bnp', 'Paribas'],
#  ['Gsk', 'Plc'],
#  ['British', 'American', 'Tobacco', 'PLC'],
#  ['Pt', 'Bank', 'Central', 'Asia', 'Tbk', 'Adr'],
#  ['Infosys', 'Ltd'],
#  ['Cme', 'Group', 'Inc'],
#  ['Compagnie', 'Financiere', 'Richemont', 'Ag', 'Fi'],
#  ['Fiserv', 'Inc'],
#  ['Canadian', 'National', 'Railway', 'Co'],
#  ['Enbridge', 'Inc'],
#  ['Canadian', 'Pacific', 'Kansas', 'City', 'LtdCn'],
#  ['Activision', 'Blizzard', 'Inc'],
#  ['Duke', 'Energy', 'Corp'],
#  ['Equinix', 'Inc'],
#  ['Vmware', 'Inc'],
#  ['Kkr', 'Co', 'Inc'],
#  ['Illinois', 'Tool', 'Works', 'Inc'],
#  ['Synopsys', 'Inc'],
#  ['Hca', 'Healthcare', 'Inc'],
#  ['Canadian', 'Natural', 'Resources', 'Ltd'],
#  ['Mercadolibre', 'Inc'],
#  ['Paypal', 'Holdings', 'Inc'],
#  ['Sherwin', 'Williams', 'Co'],
#  ['Aon', 'Plc'],
#  ['Sumitomo', 'Mitsui', 'Financial', 'Group', 'Inc'],
#  ['Air', 'Products', 'Chemicals', 'Inc'],
#  ['Abb', 'Ltd'],
#  ['Kla', 'Corp'],
#  ['Enel', 'Societa', 'Per', 'Azioni'],
#  ['Intercontinental', 'Exchange', 'Inc'],
#  ['Glencore', 'PlcAdr'],
#  ['Tokyo', 'Electron', 'Ltd'],
#  ['Cadence', 'Design', 'Systems', 'Inc'],
#  ['Charter', 'Communications', 'Inc', 'Mo'],
#  ['Netease', 'Inc'],
#  ['Waste', 'Management', 'Inc'],
#  ['Relx', 'Plc'],
#  ['Workday', 'Inc'],
#  ['Northrop', 'Grumman', 'Corp', 'De'],
#  ['Atlas', 'Copco', 'Ab'],
#  ['Fedex', 'Corp'],
#  ['ShinEtsu', 'Chemical', 'Co', 'Ltd'],
#  ['Moodys', 'Corp', 'De'],
#  ['Bank', 'Of', 'Montreal', 'Can'],
#  ['Marathon', 'Petroleum', 'Corp'],
#  ['Csx', 'Corp'],
#  ['Southern', 'Copper', 'Corp'],
#  ['Colgate', 'Palmolive', 'Co'],
#  ['Marriott', 'International', 'Inc', 'Md'],
#  ['General', 'Dynamics', 'Corp'],
#  ['Monster', 'Beverage', 'Corp'],
#  ['Banco', 'Santander', 'SA'],
#  ['Vale', 'SA'],
#  ['Humana', 'Inc'],
#  ['Stellantis', 'NV'],
#  ['Occidental', 'Petroleum', 'Corp', 'De'],
#  ['Enterprise', 'Products', 'Partners', 'LP'],
#  ['Thomson', 'Reuters', 'Corp', 'Can'],
#  ['Arista', 'Networks', 'Inc'],
#  ['America', 'Movil', 'Sab', 'De', 'Cv'],
#  ['Brookfield', 'Corp', 'On'],
#  ['Bank', 'Of', 'Nova', 'Scotia'],
#  ['FreeportMcmoran', 'Inc'],
#  ['Oriental', 'Land', 'Co', 'LtdAdr'],
#  ['Mckesson', 'Corp'],
#  ['Target', 'Corp'],
#  ['Honda', 'Motor', 'Co', 'Ltd'],
#  ['Co'],
#  ['Reilly', 'Automotive', 'Inc'],
#  ['Emerson', 'Electric', 'Co'],
#  ['Itau', 'Unibanco', 'Holding', 'SA'],
#  ['Us', 'Bancorp', 'De'],
#  ['Pioneer', 'Natural', 'Resources', 'Co'],
#  ['Phillips'],
#  ['Estee', 'Lauder', 'Companies', 'Inc'],
#  ['Snowflake', 'Inc'],
#  ['Ferrari', 'NV'],
#  ['Atlassian', 'Corp'],
#  ['Eni', 'Spa'],
#  ['Roper', 'Technologies', 'Inc'],
#  ['Chipotle', 'Mexican', 'Grill', 'Inc'],
#  ['Cintas', 'Corp'],
#  ['Nxp', 'Semiconductors', 'NV'],
#  ['Apollo', 'Global', 'Management', 'Inc'],
#  ['Ecolab', 'Inc'],
#  ['Amphenol', 'Corp', 'De'],
#  ['Dell', 'Technologies', 'Inc'],
#  ['Valero', 'Energy', 'CorpTx'],
#  ['Ford', 'Motor', 'Co'],
#  ['JdCom', 'Inc'],
#  ['Eidp', 'Inc'],
#  ['Parker', 'Hannifin', 'Corp'],
#  ['Takeda', 'Pharmaceutical', 'Co', 'Ltd'],
#  ['Fortinet', 'Inc'],
#  ['Arthur', 'Gallagher', 'Co'],
#  ['Lululemon', 'Athletica', 'Inc'],
#  ['Pnc', 'Financial', 'Services', 'Group', 'Inc'],
#  ['Anz', 'Group', 'Holdings', 'LimitedAdr'],
#  ['Hess', 'Corp'],
#  ['Baidu', 'Inc'],
#  ['Ing', 'Groep', 'Nv'],
#  ['Marvell', 'Technology', 'Inc'],
#  ['Public', 'Storage'],
#  ['Metlife', 'Inc'],
#  ['Republic', 'Services', 'Inc'],
#  ['Constellation', 'Brands', 'Inc'],
#  ['Transdigm', 'Group', 'Inc'],
#  ['Trane', 'Technologies', 'Plc'],
#  ['National', 'Grid', 'Plc'],
#  ['Pernod', 'Ricard', 'Fi'],
#  ['Motorola', 'Solutions', 'Inc'],
#  ['Keurig', 'Dr', 'Pepper', 'Inc'],
#  ['Autozone', 'Inc'],
#  ['General', 'Motors', 'Co'],
#  ['Spdr', 'Gold', 'Trust'],
#  ['Old', 'Dominion', 'Freight', 'Line', 'Inc'],
#  ['Woodside', 'Energy', 'Group', 'Ltd'],
#  ['Carrier', 'Global', 'Corp'],
#  ['Autodesk', 'Inc'],
#  ['Mizuho', 'Financial', 'Group', 'Inc'],
#  ['Banco', 'Bilbao', 'Vizcaya', 'Argentaria', 'SA'],
#  ['Sempra'],
#  ['Norfolk', 'Southern', 'Corp'],
#  ['Aflac', 'Inc'],
#  ['Suncor', 'Energy', 'Inc'],
#  ['Edwards', 'Lifesciences', 'Corp'],
#  ['Ambev', 'SA'],
#  ['Paccar', 'Inc'],
#  ['Paychex', 'Inc'],
#  ['Msci', 'Inc'],
#  ['Microchip', 'Technology', 'Inc'],
#  ['American', 'International', 'Group', 'Inc'],
#  ['Welltower', 'Inc'],
#  ['Simon', 'Property', 'Group', 'Inc', 'De'],
#  ['Hershey', 'Co'],
#  ['Copart', 'Inc'],
#  ['ArcherDanielsMidland', 'Co'],
#  ['PgE', 'Corp'],
#  ['Energy', 'Transfer', 'Lp'],
#  ['Kimberly', 'Clark', 'Corp'],
#  ['Crown', 'Castle', 'Inc'],
#  ['On', 'Semiconductor', 'Corp'],
#  ['Trade', 'Desk', 'Inc'],
#  ['Kenvue', 'Inc'],
#  ['Williams', 'Companies', 'Inc'],
#  ['Moderna', 'Inc'],
#  ['Exelon', 'Corp'],
#  ['Dexcom', 'Inc'],
#  ['American', 'Electric', 'Power', 'Co', 'Inc'],
#  ['Banco', 'Santander', 'Brasil', 'SA'],
#  ['Kraft', 'Heinz', 'Co'],
#  ['Li', 'Auto', 'Inc'],
#  ['Crowdstrike', 'Holdings', 'Inc'],
#  ['Bae', 'Systems', 'Plc', 'Fi'],
#  ['Hilton', 'Worldwide', 'Holdings', 'Inc'],
#  ['Dominion', 'Energy', 'Inc'],
#  ['Te', 'Connectivity', 'Ltd'],
#  ['Stmicroelectronics', 'NV'],
#  ['Nucor', 'Corp'],
#  ['Alcon', 'Inc'],
#  ['Ross', 'Stores', 'Inc'],
#  ['Iqvia', 'Holdings', 'Inc'],
#  ['Digital', 'Realty', 'Trust', 'Inc'],
#  ['Vinfast', 'Auto', 'Ltd'],
#  ['Crh', 'Public', 'Ltd', 'Co'],
#  ['Realty', 'Income', 'Corp'],
#  ['Cheniere', 'Energy', 'Inc'],
#  ['Johnson', 'Controls', 'International', 'Plc'],
#  ['Seagen', 'Inc'],
#  ['Cenovus', 'Energy', 'Inc'],
#  ['Horton', 'Inc', 'De'],
#  ['Interactive', 'Brokers', 'Group', 'Inc'],
#  ['Kinder', 'Morgan', 'Inc'],
#  ['Idexx', 'Laboratories', 'Inc', 'De'],
#  ['General', 'Mills', 'Inc'],
#  ['Capital', 'One', 'Financial', 'Corp'],
#  ['Truist', 'Financial', 'Corp'],
#  ['Bce', 'Inc'],
#  ['Halliburton', 'Co'],
#  ['Credit', 'Agricole'],
#  ['Haleon', 'Plc'],
#  ['Las', 'Vegas', 'Sands', 'Corp'],
#  ['Travelers', 'Companies', 'Inc'],
#  ['Canadian', 'Imperial', 'Bank', 'Of', 'Commerce', 'Can'],
#  ['Corteva', 'Inc'],
#  ['Dow', 'Inc'],
#  ['Biogen', 'Inc'],
#  ['Centene', 'Corp'],
#  ['Baker', 'Hughes', 'Co'],
#  ['Lafargeholcim', 'LtdAdr'],
#  ['Waste', 'Connections', 'Inc'],
#  ['Tc', 'Energy', 'Corp'],
#  ['Nu', 'Holdings', 'Ltd'],
#  ['Yum', 'Brands', 'Inc'],
#  ['Cognizant', 'Technology', 'Solutions', 'Corp'],
#  ['Cencora', 'Inc'],
#  ['Pt', 'Bank', 'Mandiri', 'Persero', 'Tbk', 'Adr'],
#  ['Verisk', 'Analytics', 'Inc'],
#  ['Ameriprise', 'Financial', 'Inc'],
#  ['Constellation', 'Energy', 'Corp'],
#  ['Sysco', 'Corp'],
#  ['Bank', 'Of', 'New', 'York', 'Mellon', 'Corp'],
#  ['Ishares', 'Gold', 'Trust'],
#  ['Prudential', 'Financial', 'Inc'],
#  ['Mplx', 'Lp'],
#  ['Ametek', 'Inc'],
#  ['Veeva', 'Systems', 'Inc'],
#  ['Manulife', 'Financial', 'Corp'],
#  ['WW', 'Grainger', 'Inc'],
#  ['Dupont', 'De', 'Nemours', 'Inc'],
#  ['Imperial', 'Oil', 'Ltd'],
#  ['Coupang', 'Inc'],
#  ['Lloyds', 'Banking', 'Group', 'Plc'],
#  ['Globalfoundries', 'Inc'],
#  ['Palantir', 'Technologies', 'Inc'],
#  ['Agilent', 'Technologies', 'Inc'],
#  ['Otis', 'Worldwide', 'Corp'],
#  ['Costar', 'Group', 'Inc'],
#  ['Electronic', 'Arts', 'Inc'],
#  ['Block', 'Inc'],
#  ['Cummins', 'Inc'],
#  ['Lennar', 'Corp', 'New'],
#  ['Rockwell', 'Automation', 'Inc'],
#  ['Fidelity', 'National', 'Information', 'Services', 'Inc'],
#  ['Global', 'Payments', 'Inc'],
#  ['Devon', 'Energy', 'CorpDe'],
#  ['Kroger', 'Co'],
#  ['Doordash', 'Inc'],
#  ['Ares', 'Management', 'Corp'],
#  ['Xcel', 'Energy', 'Inc'],
#  ['Bank', 'Bradesco'],
#  ['LHarris', 'Technologies', 'Inc', 'De'],
#  ['Lyondellbasell', 'Industries', 'NV'],
#  ['Experian', 'Group', 'Ltd'],
#  ['Datadog', 'Inc'],
#  ['Ferguson', 'Plc'],
#  ['Vici', 'Properties', 'Inc'],
#  ['Consolidated', 'Edison', 'Inc'],
#  ['Prudential', 'Plc'],
#  ['Ppg', 'Industries', 'Inc'],
#  ['Fastenal', 'Co'],
#  ['Orange'],
#  ['Newmont', 'Corp', 'De'],
#  ['Brown', 'Forman', 'Corp'],
#  ['Compagnie', 'De', 'Saint', 'Gobain'],
#  ['Nutrien', 'Ltd'],
#  ['Posco', 'Holdings', 'Inc'],
#  ['Public', 'Service', 'Enterprise', 'Group', 'Inc'],
#  ['Restaurant', 'Brands', 'International', 'Inc'],
#  ['United', 'Rentals', 'Inc'],
#  ['Argenx', 'Se'],
#  ['Spotify', 'Technology', 'SA'],
#  ['Barclays', 'Plc'],
#  ['Oneok', 'Inc', 'New'],
#  ['Wolters', 'Kluwer', 'Fi'],
#  ['Ge', 'Healthcare', 'Technologies', 'Inc'],
#  ['Arch', 'Capital', 'Group', 'Ltd'],
#  ['West', 'Pharmaceutical', 'Services', 'Inc'],
#  ['Quanta', 'Services', 'Inc'],
#  ['Osterreichische', 'Elektrizitatswirtschafts', 'Fi'],
#  ['Sun', 'Life', 'Financial', 'Inc'],
#  ['Mobileye', 'Global', 'Inc'],
#  ['Telstra', 'Group', 'Ltd'],
#  ['CocaCola', 'Europacific', 'Partners', 'Plc'],
#  ['Aptiv', 'Plc'],
#  ['Allstate', 'Corp'],
#  ['Chunghwa', 'Telecom', 'Co', 'Ltd'],
#  ['Vulcan', 'Materials', 'Co'],
#  ['Spdr', 'Dow', 'Jones', 'Industrial', 'Average', 'Etf', 'Trust'],
#  ['Barrick', 'Gold', 'Corp'],
#  ['Hp', 'Inc'],
#  ['Cdw', 'Corp'],
#  ['Biontech', 'Se'],
#  ['Diamondback', 'Energy', 'Inc'],
#  ['Warner', 'Bros', 'Discovery', 'Inc'],
#  ['Gartner', 'Inc'],
#  ['GreatWest', 'Lifeco', 'Inc'],
#  ['Wipro', 'Ltd'],
#  ['Banco', 'Do', 'Brasil', 'SA'],
#  ['Extra', 'Space', 'Storage', 'Inc'],
#  ['Edison', 'International'],
#  ['American', 'Water', 'Works', 'Company', 'Inc'],
#  ['Wec', 'Energy', 'Group', 'Inc'],
#  ['Ansys', 'Inc'],
#  ['Franco', 'Nevada', 'Corp'],
#  ['Vodafone', 'Group', 'Public', 'Ltd', 'Co'],
#  ['Hubspot', 'Inc'],
#  ['Martin', 'Marietta', 'Materials', 'Inc'],
#  ['Corning', 'Inc', 'Ny'],
#  ['Mongodb', 'Inc'],
#  ['Fortive', 'Corp'],
#  ['Panasonic', 'Corp'],
#  ['Alnylam', 'Pharmaceuticals', 'Inc'],
#  ['Horizon', 'Therapeutics', 'Public', 'Ltd', 'Co'],
#  ['Ingersoll', 'Rand', 'Inc'],
#  ['Dollar', 'General', 'Corp'],
#  ['Cheniere', 'Energy', 'Partners', 'LP'],
#  ['Natwest', 'Group', 'Plc'],
#  ['Fanuc', 'Ltd'],
#  ['Central', 'Japan', 'Railway', 'Co'],
#  ['Spdr', 'SP', 'Midcap', 'Etf', 'Trust'],
#  ['Avalonbay', 'Communities', 'Inc'],
#  ['Delta', 'Air', 'Lines', 'Inc'],
#  ['Zimmer', 'Biomet', 'Holdings', 'Inc'],
#  ['Nasdaq', 'Inc'],
#  ['Ecopetrol', 'SA'],
#  ['Royal', 'Caribbean', 'Cruises', 'Ltd'],
#  ['Dollar', 'Tree', 'Inc'],
#  ['Align', 'Technology', 'Inc'],
#  ['Mettler', 'Toledo', 'International', 'Inc'],
#  ['Take', 'Two', 'Interactive', 'Software', 'Inc'],
#  ['Energy', 'Co', 'Of', 'Parana'],
#  ['Telus', 'Corp'],
#  ['Price', 'Rowe', 'Group', 'Inc'],
#  ['Cgi', 'Inc'],
#  ['Cbre', 'Group', 'Inc'],
#  ['Canon', 'Inc'],
#  ['Equifax', 'Inc'],
#  ['Telefonica'],
#  ['Illumina', 'Inc'],
#  ['Perusahaan',
#   'Perseroan',
#   'Persero',
#   'Pt',
#   'Telekomunikasi',
#   'Indonesia',
#   'Tbk'],
#  ['Genmab', 'AS'],
#  ['Keysight', 'Technologies', 'Inc'],
#  ['Equity', 'Residential'],
#  ['TripCom', 'Group', 'Ltd'],
#  ['Church', 'Dwight', 'Co', 'Inc', 'De'],
#  ['Tractor', 'Supply', 'Co', 'De'],
#  ['Agnico', 'Eagle', 'Mines', 'Ltd'],
#  ['Weyerhaeuser', 'Co'],
#  ['Ebay', 'Inc'],
#  ['Zscaler', 'Inc'],
#  ['Sba', 'Communications', 'Corp'],
#  ['Xylem', 'Inc'],
#  ['Steris', 'Plc'],
#  ['Monolithic', 'Power', 'Systems', 'Inc'],
#  ['State', 'Street', 'Corp'],
#  ['Ryanair', 'Holdings', 'Plc'],
#  ['Orix', 'Corp'],
#  ['Straumann', 'Holding', 'Ag', 'Adr'],
#  ['Fair', 'Isaac', 'Corp'],
#  ['Nokia', 'Corp'],
#  ['Broadridge', 'Financial', 'Solutions', 'Inc'],
#  ['Rivian', 'Automotive', 'Inc', 'De'],
#  ['Eversource', 'Energy'],
#  ['Yum', 'China', 'Holdings', 'Inc'],
#  ['Raymond', 'James', 'Financial', 'Inc'],
#  ['Cardinal', 'Health', 'Inc'],
#  ['Discover', 'Financial', 'Services'],
#  ['Hartford', 'Financial', 'Services', 'Group', 'Inc'],
#  ['Deutsche', 'Bank', 'Aktiengesellschaft'],
#  ['Sea', 'Ltd'],
#  ['Dte', 'Energy', 'Co'],
#  ['Teck', 'Resources', 'Ltd'],
#  ['Icon', 'Plc'],
#  ['Resmed', 'Inc'],
#  ['Albemarle', 'Corp'],
#  ['Cloudflare', 'Inc'],
#  ['Hewlett', 'Packard', 'Enterprise', 'Co'],
#  ['Rogers', 'Communications', 'Inc'],
#  ['Mccormick', 'Co', 'Inc'],
#  ['Ke', 'Holdings', 'Inc'],
#  ['Coterra', 'Energy', 'Inc'],
#  ['Willis', 'Towers', 'Watson', 'Plc'],
#  ['Beigene', 'Ltd'],
#  ['Ameren', 'Corp'],
#  ['Arcelormittal'],
#  ['Invitation', 'Homes', 'Inc'],
#  ['Zoom', 'Video', 'Communications', 'Inc'],
#  ['Genuine', 'Parts', 'Co'],
#  ['Firstenergy', 'Corp'],
#  ['MT', 'Bank', 'Corp'],
#  ['Brown', 'Brown', 'Inc'],
#  ['Fairfax', 'Financial', 'Holdings', 'Ltd', 'Can'],
#  ['Advantest', 'Corp'],
#  ['Splunk', 'Inc'],
#  ['Entergy', 'Corp', 'De'],
#  ['Verisign', 'IncCa'],
#  ['Hormel', 'Foods', 'Corp', 'De'],
#  ['Ulta', 'Beauty', 'Inc'],
#  ['Garmin', 'Ltd'],
#  ['Kellogg', 'Co'],
#  ['Fleetcor', 'Technologies', 'Inc'],
#  ['Ntt', 'Data', 'Corp'],
#  ['Nvr', 'Inc'],
#  ['Markel', 'Group', 'Inc'],
#  ['Heico', 'Corp'],
#  ['Tradeweb', 'Markets', 'Inc'],
#  ['Fortis', 'Inc'],
#  ['Zto', 'Express', 'Cayman', 'Inc'],
#  ['Dover', 'Corp'],
#  ['Koninklijke', 'Philips', 'Nv'],
#  ['Hunt', 'Transport', 'Services', 'Inc'],
#  ['Baxter', 'International', 'Inc'],
#  ['Carnival', 'Corp'],
#  ['Howmet', 'Aerospace', 'Inc'],
#  ['First', 'Citizens', 'Bancshares', 'Inc', 'De'],
#  ['Wheaton', 'Precious', 'Metals', 'Corp'],
#  ['Rocket', 'Companies', 'Inc'],
#  ['Alexandria', 'Real', 'Estate', 'Equities', 'Inc'],
#  ['Disco', 'CorporationAdr'],
#  ['Molina', 'Healthcare', 'Inc'],
#  ['Live', 'Nation', 'Entertainment', 'Inc'],
#  ['Teledyne', 'Technologies', 'Inc'],
#  ['Westinghouse', 'Air', 'Brake', 'Technologies', 'Corp'],
#  ['Tenaris', 'Sa'],
#  ['Targa', 'Resources', 'Corp'],
#  ['Coinbase', 'Global', 'Inc'],
#  ['Walgreens', 'Boots', 'Alliance', 'Inc'],
#  ['Ppl', 'Corp'],
#  ['Tyson', 'Foods', 'Inc'],
#  ['United', 'Microelectronics', 'Corp'],
#  ['Lpl', 'Financial', 'Holdings', 'Inc'],
#  ['Rentokil', 'Initial', 'Plc', 'Fi'],
#  ['Fifth', 'Third', 'Bancorp'],
#  ['First', 'Solar', 'Inc'],
#  ['Iron', 'Mountain', 'Inc'],
#  ['Clorox', 'Co', 'De'],
#  ['Principal', 'Financial', 'Group', 'Inc'],
#  ['Centerpoint', 'Energy', 'Inc'],
#  ['Laboratory', 'Corp', 'Of', 'America', 'Holdings'],
#  ['Nio', 'Inc'],
#  ['Darden', 'Restaurants', 'Inc'],
#  ['Symbotic', 'Inc'],
#  ['Meta', 'Data', 'Ltd'],
#  ['Pinterest', 'Inc'],
#  ['Eqt', 'Corp'],
#  ['Hologic', 'Inc'],
#  ['Rollins', 'Inc'],
#  ['Cnh', 'Industrial', 'NV'],
#  ['Expeditors', 'International', 'Of', 'Washington', 'Inc'],
#  ['Coca', 'Cola', 'Femsa', 'Sab', 'De', 'Cv'],
#  ['Ventas', 'Inc'],
#  ['Biomarin', 'Pharmaceutical', 'Inc'],
#  ['International', 'Flavors', 'Fragrances', 'Inc'],
#  ['Atmos', 'Energy', 'Corp'],
#  ['Brazilian', 'Electric', 'Power', 'Co'],
#  ['Roblox', 'Corp'],
#  ['Chemical', 'Mining', 'Co', 'Of', 'Chile', 'Inc'],
#  ['Cooper', 'Companies', 'Inc'],
#  ['Pultegroup', 'IncMi'],
#  ['Bungeltd'],
#  ['Blue', 'Owl', 'Capital', 'Inc'],
#  ['Southwest', 'Airlines', 'Co'],
#  ['Carnival', 'Plc'],
#  ['Pembina', 'Pipeline', 'Corp'],
#  ['Cameco', 'Corp'],
#  ['Ericsson', 'Lm', 'Telephone', 'Co'],
#  ['Hubbell', 'Inc'],
#  ['Warner', 'Music', 'Group', 'Corp'],
#  ['Regions', 'Financial', 'Corp'],
#  ['Cincinnati', 'Financial', 'Corp'],
#  ['Sgs', 'Societe', 'Generale', 'De', 'Surveillance', 'Holding', 'Sa', 'Fi'],
#  ['Cms', 'Energy', 'Corp'],
#  ['Ase', 'Technology', 'Holding', 'Co', 'Ltd'],
#  ['Brookfield', 'Renewable', 'Partners', 'LP'],
#  ['Jacobs', 'Solutions', 'Inc'],
#  ['Ptc', 'Inc'],
#  ['Builders', 'Firstsource', 'Inc'],
#  ['Mid', 'America', 'Apartment', 'Communities', 'Inc'],
#  ['Factset', 'Research', 'Systems', 'Inc'],
#  ['Netapp', 'Inc'],
#  ['Berkley', 'Corp'],
#  ['Enphase', 'Energy', 'Inc'],
#  ['Steel', 'Dynamics', 'Inc'],
#  ['Idex', 'Corp', 'De'],
#  ['Sirius', 'Xm', 'Holdings', 'Inc'],
#  ['Everest', 'Group', 'Ltd'],
#  ['Marathon', 'Oil', 'Corp'],
#  ['Paycom', 'Software', 'Inc'],
#  ['Kb', 'Financial', 'Group', 'Inc'],
#  ['Ball', 'Corp'],
#  ['Cboe', 'Global', 'Markets', 'Inc'],
#  ['Magna', 'International', 'Inc'],
#  ['Tyler', 'Technologies', 'Inc'],
#  ['Waters', 'Corp', 'De'],
#  ['Sun', 'Communities', 'Inc'],
#  ['Akamai', 'Technologies', 'Inc'],
#  ['Uwm', 'Holdings', 'Corp'],
#  ['Xpeng', 'Inc'],
#  ['Check', 'Point', 'Software', 'Technologies', 'Ltd'],
#  ['Best', 'Buy', 'Co', 'Inc'],
#  ['Samsara', 'Inc'],
#  ['Westlake', 'Corp'],
#  ['Cf', 'Industries', 'Holdings', 'Inc'],
#  ['Axon', 'Enterprise', 'Inc'],
#  ['Transunion'],
#  ['Celsius', 'Holdings', 'Inc'],
#  ['Huntington', 'Bancshares', 'Inc', 'Md'],
#  ['Omnicom', 'Group', 'Inc'],
#  ['Skyworks', 'Solutions', 'Inc'],
#  ['Reliance', 'Steel', 'Aluminum', 'Co'],
#  ['Expedia', 'Group', 'Inc'],
#  ['Snap', 'Inc'],
#  ['Teradyne', 'Inc'],
#  ['Erie', 'Indemnity', 'Co'],
#  ['Epam', 'Systems', 'Inc'],
#  ['United', 'Airlines', 'Holdings', 'Inc'],
#  ['American', 'Homes', 'Rent'],
#  ['Booz', 'Allen', 'Hamilton', 'Holding', 'Corp'],
#  ['Sompo', 'Japan', 'Nipponkoa', 'Holdings', 'IncAdr'],
#  ['Textron', 'Inc'],
#  ['Okta', 'Inc'],
#  ['Northern', 'Trust', 'Corp'],
#  ['Fox', 'Corp'],
#  ['Essex', 'Property', 'Trust', 'Inc'],
#  ['Jeronimo', 'Martins', 'Sgps', 'Sa'],
#  ['Brookfield', 'Infrastructure', 'Partners', 'LP'],
#  ['Avery', 'Dennison', 'Corp'],
#  ['Mgm', 'Resorts', 'International'],
#  ['Avantor', 'Inc'],
#  ['Telefonica', 'Brasil', 'SA'],
#  ['Loews', 'Corp'],
#  ['Quest', 'Diagnostics', 'Inc'],
#  ['Heidelbergcement', 'Ag'],
#  ['Bentley', 'Systems', 'Inc'],
#  ['Lamb', 'Weston', 'Holdings', 'Inc'],
#  ['Draftkings', 'Inc'],
#  ['Shinhan', 'Financial', 'Group', 'Co', 'Ltd'],
#  ['Entegris', 'Inc'],
#  ['Applovin', 'Corp'],
#  ['Super', 'Micro', 'Computer', 'Inc'],
#  ['Xp', 'Inc'],
#  ['Unity', 'Software', 'Inc'],
#  ['Exact', 'Sciences', 'Corp'],
#  ['Incyte', 'Corp'],
#  ['Michelin',
#   'Compagnie',
#   'Generale',
#   'Des',
#   'Etablissements',
#   'Michelin',
#   'Fi'],
#  ['Vertiv', 'Holdings', 'Co'],
#  ['Aercap', 'Holdings', 'NV'],
#  ['Jabil', 'Inc'],
#  ['Dynatrace', 'Inc'],
#  ['Western', 'Digital', 'Corp'],
#  ['Revvity', 'Inc'],
#  ['Dominos', 'Pizza', 'Inc'],
#  ['Deckers', 'Outdoor', 'Corp'],
#  ['Carlisle', 'Companies', 'Inc'],
#  ['Magellan', 'Midstream', 'Partners', 'LP'],
#  ['Grab', 'Holdings', 'Ltd'],
#  ['SnapOn', 'Inc'],
#  ['Molson', 'Coors', 'Beverage', 'Co'],
#  ['Koninklijke', 'Kpn'],
#  ['Texas', 'Pacific', 'Land', 'Corp'],
#  ['Watsco', 'Inc'],
#  ['Conagra', 'Brands', 'Inc'],
#  ['Brookfield', 'Asset', 'Management', 'Ltd'],
#  ['Albertsons', 'Companies', 'Inc'],
#  ['Pool', 'Corp'],
#  ['SsC', 'Technologies', 'Holdings', 'Inc'],
#  ['Udr', 'Inc'],
#  ['Carey', 'Inc'],
#  ['Suzano', 'SA'],
#  ['Celanese', 'Corp'],
#  ['Lucid', 'Group', 'Inc'],
#  ['Liberty', 'Broadband', 'Corp'],
#  ['Lennox', 'International', 'Inc'],
#  ['Lkq', 'Corp'],
#  ['Avangrid', 'Inc'],
#  ['Amcor', 'Plc'],
#  ['Stanley', 'Black', 'Decker', 'Inc'],
#  ['Packaging', 'Corp', 'Of', 'America'],
#  ['Synchrony', 'Financial'],
#  ['Smucker', 'Co'],
#  ['Shionogi', 'Co', 'Ltd'],
#  ['Nordson', 'Corp'],
#  ['Seagate', 'Technology', 'Holdings', 'Plc'],
#  ['Alliant', 'Energy', 'Corp'],
#  ['Pt', 'Chandra', 'Asri', 'Petrochemical', 'TbkAdr'],
#  ['Ovintiv', 'Inc'],
#  ['Citizens', 'Financial', 'Group', 'IncRi'],
#  ['Leidos', 'Holdings', 'Inc'],
#  ['Intercontinental', 'Hotels', 'Group', 'Plc', 'New'],
#  ['Nomura', 'Holdings', 'Inc'],
#  ['Royalty', 'Pharma', 'Plc'],
#  ['Bouygues', 'Sa'],
#  ['Franklin', 'Resources', 'Inc'],
#  ['Fresenius', 'Medical', 'Care', 'Ag', 'Co', 'Kgaa'],
#  ['Zebra', 'Technologies', 'Corp'],
#  ['Apa', 'Corp'],
#  ['Henderson', 'Land', 'Development', 'Company', 'Ltd', 'Fi'],
#  ['Equity', 'Lifestyle', 'Properties', 'Inc'],
#  ['Carmax', 'Inc'],
#  ['Gaming', 'Leisure', 'Properties', 'Inc'],
#  ['Aspen', 'Technology', 'Inc'],
#  ['Ryan', 'Specialty', 'Holdings', 'Inc'],
#  ['Campbell', 'Soup', 'Co'],
#  ['World', 'Group', 'Ltd'],
#  ['Graco', 'Inc'],
#  ['James', 'Hardie', 'Industries', 'Plc'],
#  ['Lenovo', 'Group', 'Ltd'],
#  ['Trimble', 'Inc'],
#  ['Rpm', 'International', 'IncDe'],
#  ['Li', 'Ning', 'Co', 'Ltd'],
#  ['Lattice', 'Semiconductor', 'Corp'],
#  ['Masco', 'Corp', 'De'],
#  ['Insulet', 'Corp'],
#  ['Mosaic', 'Co'],
#  ['Turk', 'Hava', 'Yollari', 'AO'],
#  ['Evergy', 'Inc'],
#  ['Manhattan', 'Associates', 'Inc'],
#  ['Gfl', 'Environmental', 'Inc'],
#  ['Gen', 'Digital', 'Inc'],
#  ['Owens', 'Corning'],
#  ['Vistra', 'Corp'],
#  ['Bill', 'Holdings', 'Inc'],
#  ['Legend', 'Biotech', 'Corp'],
#  ['Galp', 'Energia', 'Sgps', 'SA'],
#  ['Match', 'Group', 'Inc'],
#  ['Interpublic', 'Group', 'Of', 'Companies', 'Inc'],
#  ['Rb', 'Global', 'Inc'],
#  ['Twilio', 'Inc'],
#  ['Viatris', 'Inc'],
#  ['News', 'Corp'],
#  ['Corebridge', 'Financial', 'Inc'],
#  ['Host', 'Hotels', 'Resorts', 'Inc'],
#  ['International', 'Paper', 'Co', 'New'],
#  ['Smith', 'Nephew', 'Plc'],
#  ['Flex', 'Ltd'],
#  ['Zillow', 'Group', 'Inc'],
#  ['Pure', 'Storage', 'Inc'],
#  ['Carlyle', 'Group', 'Inc'],
#  ['Nice', 'Ltd'],
#  ['Teva', 'Pharmaceutical', 'Industries', 'Ltd'],
#  ['Dr', 'Reddys', 'Laboratories', 'Ltd'],
#  ['Fidelity', 'National', 'Financial', 'Inc'],
#  ['Aecom'],
#  ['BioTechne', 'Corp'],
#  ['Chesapeake', 'Energy', 'Corp'],
#  ['Kimco', 'Realty', 'Corp'],
#  ['Ceridian', 'Hcm', 'Holding', 'Inc'],
#  ['Regency', 'Centers', 'Corp'],
#  ['Aes', 'Corp'],
#  ['Nisource', 'Inc'],
#  ['Tfi', 'International', 'Inc'],
#  ['Caesars', 'Entertainment', 'Inc'],
#  ['Saia', 'Inc'],
#  ['Neurocrine', 'Biosciences', 'Inc'],
#  ['Siam', 'Makro', 'Public', 'Co', 'LimitedAdr'],
#  ['Roku', 'Inc'],
#  ['Hf', 'Sinclair', 'Corp'],
#  ['Logitech', 'International', 'SA'],
#  ['Toast', 'Inc'],
#  ['Hyatt', 'Hotels', 'Corp'],
#  ['Gold', 'Fields', 'Ltd'],
#  ['Sarepta', 'Therapeutics', 'Inc'],
#  ['Zoominfo', 'Technologies', 'Inc'],
#  ['Godaddy', 'Inc'],
#  ['Rexford', 'Industrial', 'Realty', 'Inc'],
#  ['Jack', 'Henry', 'Associates', 'Inc'],
#  ['Ares', 'Capital', 'Corp'],
#  ['Tencent', 'Music', 'Entertainment', 'Group'],
#  ['Camden', 'Property', 'Trust'],
#  ['Ypf', 'Sociedad', 'Anonima'],
#  ['Healthpeak', 'Properties', 'Inc'],
#  ['Crown', 'Holdings', 'Inc'],
#  ['Credicorp', 'Ltd'],
#  ['BioRad', 'Laboratories', 'Inc'],
#  ['Penske', 'Automotive', 'Group', 'Inc'],
#  ['Pentair', 'Plc'],
#  ['Penumbra', 'Inc'],
#  ['Wynn', 'Resorts', 'Ltd'],
#  ['Paylocity', 'Holding', 'Corp'],
#  ['Keycorp', 'New'],
#  ['Morningstar', 'Inc'],
#  ['Cna', 'Financial', 'Corp'],
#  ['Plains', 'All', 'American', 'Pipeline', 'Lp'],
#  ['UHaul', 'Holding', 'Co', 'Nv'],
#  ['Open', 'Text', 'Corp'],
#  ['Charles', 'River', 'Laboratories', 'International', 'Inc'],
#  ['United', 'Therapeutics', 'Corp'],
#  ['Globe', 'Life', 'Inc'],
#  ['Smith', 'Corp'],
#  ['Bank', 'Of', 'Chile'],
#  ['Amdocs', 'Ltd'],
#  ['Emera', 'Inc'],
#  ['Wpp', 'Plc'],
#  ['Lincoln', 'Electric', 'Holdings', 'Inc'],
#  ['Caseys', 'General', 'Stores', 'Inc'],
#  ['Uipath', 'Inc'],
#  ['Renaissancere', 'Holdings', 'Ltd'],
#  ['Emcor', 'Group', 'Inc'],
#  ['Confluent', 'Inc'],
#  ['Robinson', 'Worldwide', 'Inc'],
#  ['Floor', 'Decor', 'Holdings', 'Inc'],
#  ['Essential', 'Utilities', 'Inc'],
#  ['Annaly', 'Capital', 'Management', 'Inc'],
#  ['Western', 'Midstream', 'Partners', 'Lp'],
#  ['Cemex', 'Sab', 'De', 'Cv'],
#  ['Teleflex', 'Inc'],
#  ['Equitable', 'Holdings', 'Inc'],
#  ['Boston', 'Properties', 'Inc'],
#  ['Accor'],
#  ['New', 'Oriental', 'Education', 'Technology', 'Group', 'Inc'],
#  ['Regal', 'Rexnord', 'Corp'],
#  ['Brookfield', 'Property', 'Partners', 'LP'],
#  ['Robinhood', 'Markets', 'Inc'],
#  ['Hasbro', 'Inc'],
#  ['Coty', 'Inc'],
#  ['Kinsale', 'Capital', 'Group', 'Inc'],
#  ['Burlington', 'Stores', 'Inc'],
#  ['Henry', 'Schein', 'Inc'],
#  ['Ubiquiti', 'Inc'],
#  ['Qiagen', 'NV'],
#  ['Alstom'],
#  ['Vail', 'Resorts', 'Inc'],
#  ['Aramark'],
#  ['Aegon', 'Nv'],
#  ['Us', 'Foods', 'Holding', 'Corp'],
#  ['Inc'],
#  ['Darling', 'Ingredients', 'Inc'],
#  ['United', 'States', 'Oil', 'Fund', 'Lp'],
#  ['Borgwarner', 'Inc'],
#  ['Fmc', 'Corp'],
#  ['DickS', 'Sporting', 'Goods', 'Inc'],
#  ['American', 'Financial', 'Group', 'Inc'],
#  ['Advanced', 'Drainage', 'Systems', 'Inc'],
#  ['Tpg', 'Inc'],
#  ['Unum', 'Group'],
#  ['Bruker', 'Corp'],
#  ['Reinsurance', 'Group', 'Of', 'America', 'Inc'],
#  ['Dropbox', 'Inc'],
#  ['Td', 'Synnex', 'Corp'],
#  ['Chewy', 'Inc'],
#  ['Omron', 'Corp', 'Fi'],
#  ['Docusign', 'Inc'],
#  ['Performance', 'Food', 'Group', 'Co'],
#  ['Allegion', 'Plc'],
#  ['Mitsubishi', 'Chemical', 'Holdings', 'Corp'],
#  ['On', 'Holding', 'Ag'],
#  ['Qorvo', 'Inc'],
#  ['Eastman', 'Chemical', 'Co'],
#  ['Service', 'Corp', 'International'],
#  ['Luckin', 'Coffee', 'Inc'],
#  ['Davita', 'Inc'],
#  ['Westrock', 'Co'],
#  ['Juniper', 'Networks', 'Inc'],
#  ['Nvent', 'Electric', 'Plc'],
#  ['Pacific', 'Airport', 'Group'],
#  ['Cubesmart'],
#  ['Gerdau', 'SA'],
#  ['Williams', 'Sonoma', 'Inc'],
#  ['Five', 'Below', 'Inc'],
#  ['Outotec', 'Oyj'],
#  ['Technipfmc', 'Plc'],
#  ['BjS', 'Wholesale', 'Club', 'Holdings', 'Inc'],
#  ['Clean', 'Harbors', 'Inc'],
#  ['Agco', 'Corp', 'De'],
#  ['Procore', 'Technologies', 'Inc'],
#  ['Elbit', 'Systems', 'Ltd'],
#  ['Repligen', 'Corp'],
#  ['Vivendi'],
#  ['Miniso', 'Group', 'Holding', 'Ltd'],
#  ['Daiwa', 'Securities', 'Group', 'Inc'],
#  ['Nrg', 'Energy', 'Inc'],
#  ['Korea', 'Electric', 'Power', 'Corp'],
#  ...]

# %%
# Parameters reference : https://www.quora.com/How-do-I-determine-Word2Vec-parameters
# Feel free to customise your own embedding

start_time = time.time()

model = Word2Vec(train_sentences, 
                 min_count = 1, vector_size = 100,
                                             window = 5, sg = 1)

print(f'Time taken : {(time.time() - start_time) / 60:.2f} mins')
# Out:
# Time taken : 0.00 mins

# %% [markdown]
# ## **Pretty fast isn't it.**
#
# Let's check out some of the features of the customised word vector.

# %%
model = Word2Vec([["a a","b","c"]], 
                 min_count = 1, vector_size = 100,
                                             window = 5, sg = 1)

# %%
# Total number of vocab in our custom word embedding
vocab_len = len(model.wv)
vocab_len
# Out:
# 3

# %%
model.wv

# %%
# Check out the dimension of each word (we set it to 100 in the above training step)

model.wv.vector_size
# Out:
# 100

# %%
model.wv.index_to_key
# Out:
# ['c', 'b', 'a a']

# %%
# Check out how 'iphone' is represented (an array of 100 numbers)

model.wv.get_vector(['a'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 # Check out how 'iphone' is represented (an array of 100 numbers)
# ----> 3 model.wv.get_vector(['a'])
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:412, in KeyedVectors.get_index(self, key, default)
#     407 def get_index(self, key, default=None):
#     408     """Return the integer index (slot/position) where the given key's vector is stored in the
#     409     backing vectors array.
#     410
#     411     """
# --> 412     val = self.key_to_index.get(key, -1)
#     413     if val >= 0:
#     414         return val
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Now, why are word embeddings powerful?
#
# This is because they capture the semantics relationships between words. In other words, words with similar meanings should appear near each other in the vector space of our custom embeddings.
#
# Lets check out an example:

# %%
model.wv.index_to_key
# Out:
# ['Inc',
#  'Corp',
#  'Ltd',
#  'Acquisition',
#  'Holdings',
#  'Group',
#  'Co',
#  'Fund',
#  'Trust',
#  'Income',
#  'Energy',
#  'Financial',
#  'Capital',
#  'Therapeutics',
#  'Technologies',
#  'International',
#  'Global',
#  'Plc',
#  'Bancorp',
#  'Holding',
#  'Technology',
#  'Ii',
#  'Pharmaceuticals',
#  'De',
#  'Bank',
#  'Investment',
#  'Resources',
#  'Partners',
#  'Health',
#  'Of',
#  'Municipal',
#  'Gold',
#  'Industries',
#  'Solutions',
#  'First',
#  'Systems',
#  'New',
#  'American',
#  'Mortgage',
#  'Ag',
#  'National',
#  'Realty',
#  'Medical',
#  'Brands',
#  'Services',
#  'SA',
#  'Power',
#  'Digital',
#  'Federal',
#  'Lp',
#  'Credit',
#  'Biosciences',
#  'Life',
#  'Blackrock',
#  'Real',
#  'Properties',
#  'Healthcare',
#  'Media',
#  'Growth',
#  'Bancshares',
#  'Opportunities',
#  'Sciences',
#  'Nuveen',
#  'Mining',
#  'America',
#  'Entertainment',
#  'United',
#  'Estate',
#  'NV',
#  'Equity',
#  'Electric',
#  'High',
#  'Iii',
#  'Star',
#  'Infrastructure',
#  'Sa',
#  'Biopharma',
#  'Can',
#  'Home',
#  'Bio',
#  'LP',
#  'Metals',
#  'Invesco',
#  'Finance',
#  'Asset',
#  'Reit',
#  'Enterprises',
#  'Western',
#  'Brookfield',
#  'Strategic',
#  'Public',
#  'Opportunity',
#  'Tech',
#  'Company',
#  'Pharma',
#  'Education',
#  'Fi',
#  'Llc',
#  'Biotech',
#  'Green',
#  'Companies',
#  'One',
#  'Silver',
#  'Pacific',
#  'Foods',
#  'Quality',
#  'Liberty',
#  'Barclays',
#  'California',
#  'Ubs',
#  'China',
#  'Communications',
#  'World',
#  'Ventures',
#  'Industrial',
#  'Loan',
#  'Management',
#  'Hospitality',
#  'Development',
#  'Montreal',
#  'Acquisitions',
#  'York',
#  'Nv',
#  'Mountain',
#  'Eaton',
#  'Storage',
#  'Vance',
#  'Diversified',
#  'Bankshares',
#  'Blue',
#  'Term',
#  'Community',
#  'Pimco',
#  'Products',
#  'Eagle',
#  'Materials',
#  'For',
#  'Royalty',
#  'Minerals',
#  'Markets',
#  'Oil',
#  'Light',
#  'Point',
#  'Southern',
#  'Golden',
#  'Networks',
#  'Investors',
#  'Dividend',
#  'Advanced',
#  'States',
#  'Water',
#  'Data',
#  'Association',
#  'Natural',
#  'Air',
#  'Iv',
#  'Usa',
#  'Northern',
#  'Ai',
#  'Worldwide',
#  'Us',
#  'Morgan',
#  'Gabelli',
#  'Preferred',
#  'Homes',
#  'Property',
#  'Insurance',
#  'Gas',
#  'Abrdn',
#  'Vision',
#  'Resource',
#  'Clean',
#  'Valley',
#  'Business',
#  'Laboratories',
#  'Value',
#  'Bioscience',
#  'Midstream',
#  'Strategies',
#  'Hotels',
#  'Fannie',
#  'Stanley',
#  'Grayscale',
#  'Software',
#  'Oak',
#  'Labs',
#  'Mae',
#  'Motor',
#  'General',
#  'On',
#  'Care',
#  'Proshares',
#  'Adr',
#  'Alpha',
#  'Securities',
#  'Land',
#  'Universal',
#  'Innovations',
#  'Dynamic',
#  'Commercial',
#  'IncDe',
#  'Gladstone',
#  'John',
#  'Horizon',
#  'Oncology',
#  'Scientific',
#  'Suisse',
#  'Biotechnology',
#  'Applied',
#  'Resorts',
#  'Fintech',
#  'Innovative',
#  'Se',
#  'The',
#  'Security',
#  'Petroleum',
#  'Integrated',
#  'Enterprise',
#  'Target',
#  'Virtus',
#  'Investments',
#  'Central',
#  'Great',
#  'Logistics',
#  'Semiconductor',
#  'Union',
#  'Yield',
#  'Electronics',
#  'Oxford',
#  'Alliance',
#  'Total',
#  'Gaming',
#  'Airlines',
#  'Franklin',
#  'Bond',
#  'Rate',
#  'Automotive',
#  'Street',
#  'Md',
#  'Lithium',
#  'Etf',
#  'Science',
#  'Asia',
#  'Service',
#  'Connecticut',
#  'Innovation',
#  'Venture',
#  'Floating',
#  'Solar',
#  'Research',
#  'Pharmaceutical',
#  'Hancock',
#  'Apollo',
#  'Emerging',
#  'Bancorporation',
#  'Wellness',
#  'Future',
#  'Citizens',
#  'Blockchain',
#  'City',
#  'Mobility',
#  'Convertible',
#  'Special',
#  'Hotel',
#  'Ameren',
#  'Fargo',
#  'Wells',
#  'Pioneer',
#  'Merger',
#  'Hill',
#  'Environmental',
#  'Bridge',
#  'Agricultural',
#  'Commodity',
#  'Riley',
#  'Marine',
#  'Cohen',
#  'Lease',
#  'CompanyMn',
#  'Cf',
#  'Quantum',
#  'Compass',
#  'Enbridge',
#  'Illinois',
#  'Goldman',
#  'Sachs',
#  'Chase',
#  'Good',
#  'LtdAdr',
#  'Biotherapeutics',
#  'Steel',
#  'Ares',
#  'Medicine',
#  'Senior',
#  'Cannabis',
#  'Fairfax',
#  'Food',
#  'Merchants',
#  'LimitedAdr',
#  'Battery',
#  'Churchill',
#  'Duration',
#  'Aviation',
#  'Mobile',
#  'Earth',
#  'Sports',
#  'Utilities',
#  'Manufacturing',
#  'Mfs',
#  'Neuberger',
#  'Generation',
#  'Mines',
#  'Plus',
#  'Two',
#  'Series',
#  'Select',
#  'Return',
#  'Hawaiian',
#  'Auto',
#  'Priority',
#  'Atlantic',
#  'Steers',
#  'Atlas',
#  'Ab',
#  'Fat',
#  'Corporate',
#  'SP',
#  'Summit',
#  'Transition',
#  'Ridge',
#  'Consumer',
#  'Physical',
#  'Enhanced',
#  'SAB',
#  'Sun',
#  'North',
#  'Core',
#  'Jpmorgan',
#  'Interactive',
#  'PgE',
#  'Shipping',
#  'Japan',
#  'System',
#  'Centers',
#  'Sachem',
#  'Texas',
#  'Impact',
#  'Chemical',
#  'Copper',
#  'Rivernorth',
#  'Beverage',
#  'Banco',
#  'Diagnostics',
#  'Empire',
#  'Sab',
#  'Blackstone',
#  'Pt',
#  'Network',
#  'Renewable',
#  'Express',
#  'Royal',
#  'Net',
#  'Cell',
#  'Nabors',
#  'Biomedical',
#  'Metal',
#  'European',
#  'Specialty',
#  'Dominion',
#  'Commerce',
#  'Harbor',
#  'Tc',
#  'Cap',
#  'State',
#  'Db',
#  'Leaf',
#  'Office',
#  'Mellon',
#  'Athena',
#  'Hudson',
#  'Voya',
#  'Smith',
#  'Thunder',
#  'Premier',
#  'Edison',
#  'Alternative',
#  'Black',
#  'Ma',
#  'Aerospace',
#  'Robotics',
#  'Noble',
#  'Devices',
#  'Principal',
#  'Aspac',
#  'Drilling',
#  'In',
#  'Coastal',
#  'Crown',
#  'Retail',
#  'Square',
#  'Planet',
#  'Grupo',
#  'House',
#  'Exploration',
#  'Bright',
#  'Maritime',
#  'Micro',
#  'Live',
#  'Deutsche',
#  'Lane',
#  'Old',
#  'Aurora',
#  'Uranium',
#  'Phoenix',
#  'Hennessy',
#  'Aktiengesellschaft',
#  'Biologics',
#  'Direct',
#  'Ocean',
#  'Entergy',
#  'Premium',
#  'Index',
#  'Online',
#  'Lending',
#  'Ny',
#  'Space',
#  'Smart',
#  'Third',
#  'Airport',
#  'Intelligent',
#  'Biopharmaceuticals',
#  'Communities',
#  'Park',
#  'Utility',
#  'Pa',
#  'Edge',
#  'Allocation',
#  'River',
#  'Nexpoint',
#  'Bitcoin',
#  'Telephone',
#  'Bdc',
#  'Red',
#  'Pipeline',
#  'Latin',
#  'Residential',
#  'Garden',
#  'Advantage',
#  'Packaging',
#  'Tankers',
#  'Sprott',
#  'Social',
#  'Century',
#  'Calamos',
#  'Projects',
#  'Investcorp',
#  'Williams',
#  'CorpDe',
#  'Kkr',
#  'Esports',
#  'Cyber',
#  'Ashford',
#  'Monterey',
#  'Tbk',
#  'Berman',
#  'Concord',
#  'Sky',
#  'Surgical',
#  'Focus',
#  'Grid',
#  'Muniyield',
#  'Mind',
#  'IncMd',
#  'Canada',
#  'Bny',
#  'Safe',
#  'Nova',
#  'Ch',
#  'US',
#  'Dynamics',
#  'Pennsylvania',
#  'Lion',
#  'Elm',
#  'Cv',
#  'Restaurant',
#  'Grade',
#  'Pono',
#  'MBrigade',
#  'Soul',
#  'Better',
#  'Internet',
#  'Republic',
#  'Fusion',
#  'Sustainable',
#  'Santander',
#  'Ready',
#  'Compagnie',
#  'Lng',
#  'Vi',
#  'Canadian',
#  'CorporationDe',
#  'Farms',
#  'Soup',
#  'Aspen',
#  'Allstate',
#  'Currencyshares',
#  'SeAdr',
#  'Roth',
#  'CV',
#  'Fortune',
#  'Vornado',
#  'Johnson',
#  'Insight',
#  'Therapies',
#  'Uk',
#  'Crest',
#  'Teucrium',
#  'Jupiter',
#  'Agnc',
#  'Arrow',
#  'View',
#  'Com',
#  'Disruptive',
#  'Fuel',
#  'Creative',
#  'Oh',
#  'Brighthouse',
#  'Chesapeake',
#  'Spectral',
#  'Granite',
#  'Ftai',
#  'Plains',
#  'Instruments',
#  'Managers',
#  'Zalatoris',
#  'Corner',
#  'Corporation',
#  'Coffee',
#  'Triton',
#  'Spac',
#  'Precious',
#  'Ellington',
#  'Cloud',
#  'Ix',
#  'Vii',
#  'Dollar',
#  'Fuels',
#  'Northwest',
#  'Molecular',
#  'Consolidated',
#  'Intelligence',
#  'Biotechnologies',
#  'Recovery',
#  'Prime',
#  'Automation',
#  'Ishares',
#  'Prudential',
#  'Origin',
#  'Genesis',
#  'AS',
#  'Portfolio',
#  'Precision',
#  'Banking',
#  'Motors',
#  'James',
#  'West',
#  'Arch',
#  'Bce',
#  'Strategy',
#  'Custom',
#  'Argo',
#  'Arlington',
#  'Charles',
#  'Canyon',
#  'Hcm',
#  'Renewables',
#  'Ofs',
#  'Toronto',
#  'Nextera',
#  'Cellular',
#  'Keycorp',
#  'AtT',
#  'Denali',
#  'Machines',
#  'Pennymac',
#  'Chimera',
#  'Verde',
#  'Project',
#  'Myers',
#  'Titan',
#  'Twin',
#  'Private',
#  'Heritage',
#  'Bit',
#  'Americas',
#  'Woods',
#  'Frontier',
#  'Top',
#  'Pure',
#  'Argentina',
#  'AmtFree',
#  'Chs',
#  'Living',
#  'Aris',
#  'Peoples',
#  'Rail',
#  'Nevada',
#  'Rf',
#  'Inception',
#  'Rise',
#  'Muniholdings',
#  'Spdr',
#  'Galaxy',
#  'Armada',
#  'Fs',
#  'Winvest',
#  'Electronic',
#  'Ault',
#  'Murphy',
#  'Costamare',
#  'Platforms',
#  'Advisors',
#  'Ligand',
#  'Climaterock',
#  'Alset',
#  'Yotta',
#  'Broad',
#  'Algonquin',
#  'Vehicles',
#  'Stone',
#  'South',
#  'Partner',
#  'Farmers',
#  'Sierra',
#  'Stifel',
#  'Portage',
#  'Factory',
#  'Columbia',
#  'Mexican',
#  'Harbors',
#  'Intermediate',
#  'Paramount',
#  'Spring',
#  'Rithm',
#  'Transportation',
#  'Spark',
#  'Pineapple',
#  'Europe',
#  'Li',
#  'Chile',
#  'Saratoga',
#  'Hub',
#  'PlcAdr',
#  'Outdoor',
#  'Lifesciences',
#  'Mlp',
#  'Music',
#  'Eastern',
#  'Cn',
#  'Rock',
#  'Carbon',
#  'Pebblebrook',
#  'Super',
#  'Brazilian',
#  'Pembina',
#  'Jaguar',
#  'Flexible',
#  'Line',
#  'Tortoise',
#  'Chicken',
#  'Esg',
#  'Cayman',
#  'TaxManaged',
#  'Beyond',
#  'Parts',
#  'Eve',
#  'India',
#  'Debt',
#  'Shack',
#  'Sterling',
#  'Cms',
#  'Flaherty',
#  'Four',
#  'Constellation',
#  'Trinity',
#  'Evergreen',
#  'Aura',
#  'Huntington',
#  'Mid',
#  'Re',
#  'Templeton',
#  'Crumrine',
#  'Tax',
#  'Oriental',
#  'CorporationAdr',
#  'Gamco',
#  'Fuse',
#  'Berkley',
#  'Brilliant',
#  'Athene',
#  'Alpine',
#  'Associated',
#  'Nustar',
#  'Source',
#  'Wave',
#  'Equipment',
#  'Store',
#  'Orchid',
#  'Altitude',
#  'Alphatime',
#  'Bellevue',
#  'Redwoods',
#  'Nano',
#  'Barings',
#  'Affiliated',
#  'Sm',
#  'Change',
#  'Triumph',
#  'Goldenstone',
#  'Tg',
#  'Bleuacacia',
#  'Globalink',
#  'Embrace',
#  'Municipals',
#  'Engineering',
#  'Fresh',
#  'Customers',
#  'SAAdr',
#  'Keyarch',
#  'Rose',
#  'Lakeshore',
#  'Hhg',
#  'Arisz',
#  'Plutonian',
#  'Legacy',
#  'AgAdr',
#  'Diamond',
#  'Qomolangma',
#  'Offshore',
#  'Kairous',
#  'Clover',
#  'Runway',
#  'Capstone',
#  'Allied',
#  'Viveon',
#  'Bukit',
#  'Jalil',
#  'Cetus',
#  'Brand',
#  'Spirit',
#  'Gc',
#  'Ut',
#  'Housing',
#  'Ecosystem',
#  'Sotherly',
#  'Zions',
#  'TaxAdvantaged',
#  'Brunswick',
#  'Lodging',
#  'Babcock',
#  'Managed',
#  'Vacations',
#  'Orion',
#  'Israel',
#  'BancCorp',
#  'Versus',
#  'Catalyst',
#  'Culture',
#  'Armour',
#  'Payment',
#  'Douglas',
#  'Urban',
#  'Biomed',
#  'Spire',
#  'Vista',
#  'Tx',
#  'Putnam',
#  'Village',
#  'Tekla',
#  'Free',
#  'Inflection',
#  'Imaging',
#  'Lab',
#  'Iconic',
#  'Wheeler',
#  'Center',
#  'Regional',
#  'Digitalbridge',
#  'Navios',
#  'Iris',
#  'Flame',
#  'Mustang',
#  'Stem',
#  'Road',
#  'Banc',
#  'Cw',
#  'Three',
#  'Standard',
#  'IncTx',
#  'Arbor',
#  'Ms',
#  'Metaverse',
#  'Rigel',
#  'Advance',
#  'Integral',
#  'Rocky',
#  'CorpPa',
#  'Accretion',
#  'Prospector',
#  'Parks',
#  'Institute',
#  'Jersey',
#  'Redwood',
#  'Hersha',
#  'Chain',
#  'Cslm',
#  'Pyxis',
#  'Wilcox',
#  'Php',
#  'Crescent',
#  'Platinum',
#  'Newtekone',
#  'Bird',
#  'Parent',
#  'Feutune',
#  'Fast',
#  'Emerald',
#  'Cactus',
#  'Op',
#  'Infinite',
#  'Allspring',
#  'Seneca',
#  'Mexico',
#  'Medicines',
#  'Patria',
#  'Guaranty',
#  'Deep',
#  'Tidewater',
#  'Hills',
#  'Wine',
#  'Epr',
#  'Apple',
#  'Imperial',
#  'Omega',
#  'Carlyle',
#  'Generale',
#  'SPA',
#  'Metlife',
#  'Ross',
#  'Taiwan',
#  'Stores',
#  'Tower',
#  'Apartment',
#  'Sk',
#  'Drive',
#  'Everest',
#  'Citigroup',
#  'Waste',
#  'Mitsubishi',
#  'Beauty',
#  'Asa',
#  'Grifols',
#  'Associates',
#  'Telecom',
#  'Lifestyle',
#  'Gaslog',
#  'Meta',
#  'Bristol',
#  'Pinnacle',
#  'Regions',
#  'Henderson',
#  'All',
#  'Depot',
#  'Transfer',
#  'Aimfinity',
#  'Koninklijke',
#  'Marathon',
#  'Lincoln',
#  'Transport',
#  'Carnival',
#  'Dte',
#  'Rocket',
#  'Reinsurance',
#  'Coca',
#  'Regency',
#  'Cola',
#  'Fifth',
#  'Novo',
#  'Supply',
#  'Restaurants',
#  'Boston',
#  'Juniper',
#  'Washington',
#  'Five',
#  'Southwest',
#  'Brasil',
#  'Reliance',
#  'Annaly',
#  'Arts',
#  'Michelin',
#  'Rent',
#  'Squibb',
#  'Berkshire',
#  'Broadband',
#  'Payments',
#  'Information',
#  'Quest',
#  'Sgps',
#  'Manulife',
#  'Brown',
#  'Ford',
#  'Truist',
#  'StratsSm',
#  'Railway',
#  'Mitsui',
#  'Cenovus',
#  'Rio',
#  'Tinto',
#  'IncAdr',
#  'Aluminum',
#  'Partnership',
#  'AbAdr',
#  'Defined',
#  'Fox',
#  'Siriuspoint',
#  'Sdcl',
#  'Finders',
#  'Pegasus',
#  'Limited',
#  'Gigcapital',
#  'Eg',
#  'Universe',
#  'Coast',
#  'Dna',
#  'Coliseum',
#  'Proptech',
#  'Apx',
#  'Banyan',
#  'Hologram',
#  'Vector',
#  'Pearl',
#  'Nft',
#  'Superior',
#  'Presto',
#  'Totalenergies',
#  'Byte',
#  'Assets',
#  'Altagas',
#  'Fortis',
#  'Vertex',
#  'Magnum',
#  'Opus',
#  'Dow',
#  'Nextgen',
#  'Textainer',
#  'Computer',
#  'Transalta',
#  'Oaktree',
#  'Country',
#  'Prospect',
#  'Providence',
#  'Arrowroot',
#  'Ship',
#  'Educational',
#  'Sizzle',
#  'Hovnanian',
#  'Lm',
#  'Selling',
#  'Disco',
#  'Construction',
#  'Dr',
#  'Mercato',
#  'Knightswan',
#  'Esgen',
#  'Independent',
#  'Cherry',
#  'Cedar',
#  'Adams',
#  'Commonwealth',
#  'Magic',
#  'Graf',
#  'Tripadvisor',
#  'Harrow',
#  'Pet',
#  'Highland',
#  'Capitalworks',
#  'Cartica',
#  'Tsakos',
#  'Transformation',
#  'Healthwell',
#  'Navigation',
#  'MultiSector',
#  'Livewire',
#  'Government',
#  'Blueriver',
#  'Climate',
#  'Comcast',
#  'Spree',
#  'Wisconsin',
#  'Artelo',
#  ...]

# %%
# Find words with similar meaning to 'iphone'

model.wv.most_similar('Bancorp')
# Out:
# [('SA', 0.9977346062660217),
#  ('Industries', 0.9974544048309326),
#  ('Brands', 0.9972704648971558),
#  ('Biosciences', 0.9972336888313293),
#  ('Bancshares', 0.9971439242362976),
#  ('Energy', 0.9971238374710083),
#  ('Systems', 0.9971027970314026),
#  ('Solutions', 0.9970887899398804),
#  ('Sa', 0.9970816969871521),
#  ('Technologies', 0.9970442056655884)]

# %% [markdown]
# Well, you will see words similar to 'iphone', sorted based on euclidean distance.
# Of cause, there are also not so intuitive and relevant ones (e.g. jetblack, cpo, ten). If you would like to tackle this, you can do a more thorough pre-processing/ try other embedding dimensions

# %% [markdown]
# ## **The most important part!**
# Last but not least, save your word embeddings, so that you can used it for modelling. You can load the text file next time using Gensim KeyedVector function.

# %%
model.wv.save_word2vec_format('custom_glove_100d.txt')


# How to load:
# w2v = KeyedVectors.load_word2vec_format('custom_glove_100d.txt')

# How to get vector using loaded model
# w2v.get_vector('iphone')

# %%
print("Cosine similarity between 'alice' " +
          "and 'wonderland' - Skip Gram : ",
    model.wv.similarity('Apple Inc', 'Apple Inc'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
#       1 print("Cosine similarity between 'alice' " +
#       2           "and 'wonderland' - Skip Gram : ",
# ----> 3     model.wv.similarity('Apple Inc', 'Apple Inc'))
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)
#    1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File /opt/homebrew/lib/python3.9/site-packages/gensim/models/keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'Apple Inc' not present"
